# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import csv

import pylidc as pl
from pylidc.Annotation import feature_names as fnames
from scipy.misc import imsave 
import PIL.Image as Image
import matplotlib.image as mpimg

import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import dicom
import scipy.ndimage
# Out:
# /home/shenxk/anaconda3/lib/python3.6/site-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)

# %% [markdown]
# ## See data statistics

# %%
root = '/home/shenxk/Documents/nodule_seg/prep_result/previous/patches'
names = np.sort(os.listdir(root))
names
# Out:
# array(['ct_patch00000000.png', 'ct_patch00000001.png',
#        'ct_patch00000002.png', ..., 'ct_patch10130400.png',
#        'ct_patch10130401.png', 'ct_patch10140000.png'],
#       dtype='<U20')

# %%
slice_number = np.array([int(names[i][-6:-4]) for i in range(len(names))])

# %%
for i in range(28):
    print('Number of nodules spanning %d slices: %d' % (i+1, np.sum(slice_number==i) - np.sum(slice_number == i+1)))
# Out:
# Number of nodules spanning 1 slices: 166
# Number of nodules spanning 2 slices: 139
# Number of nodules spanning 3 slices: 114
# Number of nodules spanning 4 slices: 89
# Number of nodules spanning 5 slices: 59
# Number of nodules spanning 6 slices: 55
# Number of nodules spanning 7 slices: 34
# Number of nodules spanning 8 slices: 25
# Number of nodules spanning 9 slices: 18
# Number of nodules spanning 10 slices: 17
# Number of nodules spanning 11 slices: 14
# Number of nodules spanning 12 slices: 4
# Number of nodules spanning 13 slices: 11
# Number of nodules spanning 14 slices: 6
# Number of nodules spanning 15 slices: 13
# Number of nodules spanning 16 slices: 6
# Number of nodules spanning 17 slices: 5
# Number of nodules spanning 18 slices: 2
# Number of nodules spanning 19 slices: 3
# Number of nodules spanning 20 slices: 3
# Number of nodules spanning 21 slices: 3
# Number of nodules spanning 22 slices: 0
# Number of nodules spanning 23 slices: 1
# ...

# %%
from prep_3d import save_slices
save_slices('/home/shenxk/data/LungCancerData/LIDC_prep/slices', id_range = [380,400])
# Out:
# Loading dicom files ... This may take a moment.
# 0380
# 258
# Loading dicom files ... This may take a moment.
# 0381
# 108
# Loading dicom files ... This may take a moment.
# 0382
# 125
# Loading dicom files ... This may take a moment.
# 0383
# 182
# Loading dicom files ... This may take a moment.
# 0384
# 101
# Loading dicom files ... This may take a moment.
# 0385
# 106
# Loading dicom files ... This may take a moment.
# 0386
# 118
# Loading dicom files ... This may take a moment.
# 0387
# 490
# Loading dicom files ... This may take a moment.
# 0388
# 445
# Loading dicom files ... This may take a moment.
# 0389
# 503
# Loading dicom files ... This may take a moment.
# 0390
# 115
# Loading dicom files ... This may take a moment.
# 0391
# 359
# Loading dicom files ... This may take a moment.
# 0392
# 113
# Loading dicom files ... This may take a moment.
# 0393
# 108
# Loading dicom files ... This may take a moment.
# 0394
# 139
# Loading dicom files ... This may take a moment.
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('/home/shenxk/data/LungCancerData/LIDC_prep/slices/0389353.png')
plt.imshow(img)
plt.show()

# %%
a = [1,2,3,4]
b = [1,2]
[a.remove(b[i]) for i in range(len(b))]
# Out:
# [None, None]

# %%
a
# Out:
# [3, 4]
